# %%
# %pip install --upgrade jamdict jamdict-data
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 203.7/203.7 kB 8.5 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.9/53.9 MB 8.5 MB/s eta 0:00:00:00:0100:01
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 70.6/70.6 kB 329.1 kB/s eta 0:00:00a 0:00:01
#   Preparing metadata (setup.py) ... done
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for jamdict: filename=jamdict-0.1a11.post2-py3-none-any.whl size=196864 sha256=be5b55235f1af749531ab7e85acdc7eeb2c650581f2a948e99f1dcb11ec34e3f
#   Stored in directory: /root/.cache/pip/wheels/02/60/d6/2f11dcdbd570b5e65a04bfb6fb9a9eeafe8004de217dbd0d11
# ...
#   Created wheel for jamdict-data: filename=jamdict_data-1.5-py3-none-any.whl size=124546829 sha256=369bf9332cd40d8151d7789f34bc6b42480ca9b78f383f5917b2ecda0a215293
# ...

# %%
from jamdict import Jamdict
import json


jam = Jamdict()

# %%
res = jam.lookup('葉')

for entry in res.chars:
    print(json.dumps(entry.to_dict()))
# Out:
# {"literal": "\u8449", "codepoints": [{"type": "ucs", "value": "8449"}, {"type": "jis208", "value": "1-45-53"}], "radicals": [{"type": "classical", "value": "140"}], "stroke_count": 12, "grade": "3", "stroke_miscounts": [], "variants": [], "freq": "414", "rad_names": [], "jlpt": "2", "dic_refs": [{"type": "nelson_c", "value": "4001", "m_vol": "", "m_page": ""}, {"type": "nelson_n", "value": "5129", "m_vol": "", "m_page": ""}, {"type": "halpern_njecd", "value": "2321", "m_vol": "", "m_page": ""}, {"type": "halpern_kkd", "value": "2912", "m_vol": "", "m_page": ""}, {"type": "halpern_kkld", "value": "1497", "m_vol": "", "m_page": ""}, {"type": "halpern_kkld_2ed", "value": "2024", "m_vol": "", "m_page": ""}, {"type": "heisig", "value": "228", "m_vol": "", "m_page": ""}, {"type": "heisig6", "value": "243", "m_vol": "", "m_page": ""}, {"type": "gakken", "value": "405", "m_vol": "", "m_page": ""}, {"type": "oneill_names", "value": "1991", "m_vol": "", "m_page": ""}, {"type": "oneill_kk", "va
# ...

# %% [markdown]
# Fields that are relevant:
#
# rm.readings -> type (ja_kun, ja_on)
# nanoris
# rm.meanings -> m_lang (for en it is empty for some reason)

# %%
rads = jam.krad['葉']
rads
# Out:
# ['木', '世', '⺾']

# %%
entries = jam.lookup('%話%').entries

for entry in entries:
    print(json.dumps(entry.to_dict()))
# Out:
# {"idseq": 1002260, "kanji": [{"text": "\u304a\u4e16\u8a71\u306b\u306a\u308b"}, {"text": "\u5fa1\u4e16\u8a71\u306b\u306a\u308b"}], "kana": [{"text": "\u304a\u305b\u308f\u306b\u306a\u308b", "nokanji": 0}], "senses": [{"pos": ["expressions (phrases, clauses, etc.)", "Godan verb with 'ru' ending"], "xref": ["\u4e16\u8a71\u306b\u306a\u308b"], "misc": ["polite (teineigo) language"], "SenseInfo": ["used to express gratitude to somebody who is about to do something for one"], "SenseGloss": [{"lang": "eng", "text": "to be much obliged (to someone)"}, {"lang": "eng", "text": "to receive favor (favour)"}, {"lang": "eng", "text": "to be indebted"}, {"lang": "eng", "text": "to be grateful"}]}]}
# ...

# %%
len(entries)
# Out:
# 447

# %%
max_vocab = 20
vocabs = []

for entry in entries[:5]:
    print(entry.to_dict()['kanji'][0]['text'])
# Out:
# お世話になる
# お話し中
# こぼし話
# ほそぼそ話す
# アドオン電話

# %% [markdown]
# Fields that are relevant
#
# kanji[].text
# kana[].text
# senses[].pos -> find out if important [verb, common, noun]
# senses[].SenseGloss[]text if lang is `eng`

# %%
# %pip install jaconv
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for jaconv: filename=jaconv-0.3.4-py3-none-any.whl size=16416 sha256=e487e6118129403f66faff6907aba28fd0db95535b99a7e05e270c20f705105a
#   Stored in directory: /root/.cache/pip/wheels/46/8f/2e/a730bf1fca05b33e532d5d91dabdf406c9b718ec85b01b1b54
# Successfully built jaconv
# ...

# %%
from tqdm import tqdm
import jaconv

subjects = []

bar = tqdm(total=6335)

with open('kanjidic', encoding='euc-jp') as f:
    # skip the first line
    next(f)
    
    for line in f:
        kanji = line[0]
        subject = {
            'characters': kanji,
            'object': 'kanji',
            'meanings': [],
            'readings': [],
            'slug': kanji}
        res = jam.lookup(kanji).chars[0]
        for i, m in enumerate(res.to_dict()['rm'][0]['meanings']):
            if m['m_lang'] == '':
                subject['meanings'].append({
                    'meaning': m['value'],
                    'primary': i == 0,
                })
        
        for r in res.to_dict()['rm'][0]['readings']: 
            if r['type'] == 'ja_on':
                subject['readings'].append({
                    'reading': jaconv.kata2hira(r['value']),
                    'type': 'onyomi',
                })
            elif r['type'] == 'ja_kun':
                subject['readings'].append({
                    'reading': jaconv.kata2hira(r['value']),
                    'type': 'kunyomi',
                })
        subject['radicals'] = jam.krad[kanji] 
        subjects.append(subject)
        bar.update(1)
# Out:
#   7%|▋         | 431/6335 [00:22<05:11, 18.95it/s]
# 6351it [03:03, 38.66it/s]

# %%
len(subjects)
# Out:
# 6355

# %%
import pandas as pd

df = pd.DataFrame(subjects)

# %%
df.tail()
# Out:
#      characters object                                           meanings  \
# 6350          槇  kanji  [{'meaning': 'twig', 'primary': True}, {'meani...
# 6351          遙  kanji  [{'meaning': 'far off', 'primary': True}, {'me...
# 6352          瑤  kanji  [{'meaning': 'beautiful (as a jewel)', 'primar...
# 6353          凜  kanji  [{'meaning': 'cold', 'primary': True}, {'meani...
# 6354          熙  kanji  [{'meaning': 'bright', 'primary': True}, {'mea...
#
#                                                readings slug  \
# 6350  [{'reading': 'てん', 'type': 'onyomi'}, {'readin...    槇
# 6351  [{'reading': 'よう', 'type': 'onyomi'}, {'readin...    遙
# 6352  [{'reading': 'よう', 'type': 'onyomi'}, {'readin...    瑤
# 6353  [{'reading': 'りん', 'type': 'onyomi'}, {'readin...    凜
# 6354  [{'reading': 'き', 'type': 'onyomi'}, {'reading...    熙
#
#                 radicals
# 6350  [木, 貝, 目, ハ, ｜, 一]
# 6351        [辶, 夕, 丶, 缶]
# 6352        [王, 夕, 丶, 缶]
# 6353        [冫, 亠, 禾, 口]
# ...

# %%
df.to_json('kanjis.jsonl', orient='records', lines=True)
