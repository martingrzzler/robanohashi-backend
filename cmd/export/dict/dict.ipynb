# %%
# %pip install --upgrade jamdict jamdict-data -q
# Out:
# Note: you may need to restart the kernel to use updated packages.

# %%
from jamdict import Jamdict
import json


jam = Jamdict()

# %%
import unicodedata

def is_kanji(char):
    try:
        name = unicodedata.name(char)
        return "CJK UNIFIED IDEOGRAPH" in name or "CJK COMPATIBILITY IDEOGRAPH" in name
    except ValueError:
        return False




text = "言葉付き"

for char in text:
    print(char, is_kanji(char))
# Out:
# 言 True
# 葉 True
# 付 True
# き False

# %%
import pandas as pd

df = pd.read_json('kanjis.jsonl', lines=True)

# %%
df.head(20)
# Out:
#    characters                        vocabulary
# 0           柾                                []
# 1           瘼                                []
# 2           祥                                []
# 3           襦                                []
# 4           當                                []
# 5           詬                                []
# 6           簇                                []
# 7           閈                                []
# 8           惕                                []
# 9           佟                                []
# 10          樌                                []
# 11          朷                                []
# 12          榲                                []
# 13          灝                                []
# 14          埏                                []
# 15          停               [各駅停車, バス停, 停止, 停電]
# 16          幎                                []
# 17          侫                                []
# 18          郞                                []
# 19          捕  [捕まる, 逮捕, 捕える, 逮捕する, 捕獲, 捕鯨, 捕虜]

# %%
kanji_set = set(df['characters'])

# %%
vocab_set = set(v for l in df['vocabulary'] for v in l)

# %%
len(kanji_set), len(vocab_set)
# Out:
# (9980, 6528)

# %%
#steps
# for each kanji search jamdict
# for word in entries
# discard if not if any character is not in kanji set
from tqdm import tqdm
import romkan

# bar = tqdm(total=len(kanji_set))

def contains_non_kanji_chars(word):
    for char in word:
        if not is_kanji(char) or char not in kanji_set:
            return True
    return False

def extract_reading(x):
    return {
        'reading': x['kana'][0]['text'],
        'primary': True,
        'romaji': romkan.to_roma(x['kana'][0]['text'])
    }

def extract_meanings(x):
    meanings = []
    for m in x['senses']:
        for o in m['SenseGloss']:
            if o['lang'] == 'eng':
                meanings.append(o['text'])
                break
    return meanings

vocabs = []

# for i, x in df.iterrows():
#     kanji = x['characters']
   
#     res = jam.lookup(f'%{kanji}%')

#     for word in res.entries:
#         word = word.to_dict()
#         if word['kanji'][0]['text'] in vocab_set:
#             continue

#         if contains_non_kanji_chars(word['kanji'][0]['text']):
#             continue
#         vocabs.append({
#             'characters': word['kanji'][0]['text'],
#             'reading': extract_reading(word),
#             'meanings': extract_meanings(word),
#             'kanjis': [k for k in word['kanji'][0]['text']]
#         })
#     bar.update(1)

# %%
import romkan
from tqdm import tqdm
from concurrent.futures import ProcessPoolExecutor
import pandas as pd

def process_row(index_row_tuple):
    i, x = index_row_tuple
    kanji = x['characters']

    res = jam.lookup(f'%{kanji}%')

    vocab_list = []

    for word in res.entries:
        word = word.to_dict()
        if word['kanji'][0]['text'] in vocab_set:
            continue

        if contains_non_kanji_chars(word['kanji'][0]['text']):
            continue
        vocab_list.append({
            'characters': word['kanji'][0]['text'],
            'reading': extract_reading(word),
            'meanings': extract_meanings(word),
            'kanjis': [k for k in word['kanji'][0]['text']]
        })

    return vocab_list

# Use a ProcessPoolExecutor for parallel processing
with ProcessPoolExecutor(max_workers=8) as executor:
    # Run process_row for each row in the DataFrame in parallel
    results = list(tqdm(executor.map(process_row, df.iterrows()), total=len(kanji_set)))

# Combine the results into a single list of vocabs
vocabs = [vocab for sublist in results for vocab in sublist]

# Update the progress bar
bar = tqdm(total=len(kanji_set))
bar.update(len(kanji_set))
# Out:
# 100%|██████████| 9980/9980 [30:00<00:00,  5.54it/s]
#   0%|          | 0/9980 [00:00<?, ?it/s]

# %%
len(vocabs)
# Out:
# 297822

# %%
df_vocab = pd.DataFrame(vocabs)

# %%
df_vocab.head(20)
# Out:
#    characters                                            reading
# 0          柾目  {'reading': 'まさめ', 'primary': True, 'romaji': ...  \
# 1          正木  {'reading': 'まさき', 'primary': True, 'romaji': ...
# 2          襦袢  {'reading': 'じゅばん', 'primary': True, 'romaji':...
# 3         肌襦袢  {'reading': 'はだじゅばん', 'primary': True, 'romaji...
# 4         肉襦袢  {'reading': 'にくじゅばん', 'primary': True, 'romaji...
# 5         長襦袢  {'reading': 'ながじゅばん', 'primary': True, 'romaji...
# 6         赤古里  {'reading': 'チョゴリ', 'primary': True, 'romaji':...
# 7         當十錢  {'reading': 'とうじゅうぜん', 'primary': True, 'romaj...
# 8          瓦当  {'reading': 'がとう', 'primary': True, 'romaji': ...
# 9         石敢當  {'reading': 'いしがんどう', 'primary': True, 'romaji...
# 10         上蔟  {'reading': 'じょうぞく', 'primary': True, 'romaji'...
# 11         族生  {'reading': 'ぞくせい', 'primary': True, 'romaji':...
# 12         大簇  {'reading': 'たいそう', 'primary': True, 'romaji':...
# 13         簇出  {'reading': 'そうしゅつ', 'primary': True, 'romaji'...
# 14          群  {'reading': 'むら', 'primary': True, 'romaji': '...
# 15          蔟  {'reading': 'まぶし', 'primary': True, 'romaji': ...
# 16         集簇  {'reading': 'しゅうぞく', 'primary': True, 'romaji'...
# 17       運転停止  {'reading': 'うんてんていし', 'primary': True, 'romaj...
# 18        急停車  {'reading': 'きゅうていしゃ', 'primary': True, 'romaj...
# 19       出港停止  {'reading': 'しゅっこうていし', 'primary': True, 'roma...
#
#                                              meanings        kanjis
# 0                                    [straight grain]        [柾, 目]
# 1         [Japanese spindletree (Euonymus japonicus)]        [正, 木]
# 2                  [undershirt (worn under a kimono)]        [襦, 袢]
# 3   [(Japanese-style) undershirt worn under nagaju...     [肌, 襦, 袢]
# 4                            [flesh-colored leotards]     [肉, 襦, 袢]
# 5   [long, kimono-like garment, made of light fabr...     [長, 襦, 袢]
# 6                                           [chogori]     [赤, 古, 里]
# 7   [type of bronze Chinese coin first issued unde...     [當, 十, 錢]
# 8           [decorative cap of an eave-end roof tile]        [瓦, 当]
# 9                                        [shigandang]     [石, 敢, 當]
# 10                              [spinning of cocoons]        [上, 蔟]
# 11                  [(of plants) growing in clusters]        [族, 生]
# 12  [(in China) 3rd note of the ancient chromatic ...        [大, 簇]
# 13                       [springing up (in clusters)]        [簇, 出]
# 14                                        [gathering]           [群]
# 15                                   [cocoon holders]           [蔟]
# 16                                      [aggregation]        [集, 簇]
# 17                         [suspension of operations]  [運, 転, 停, 止]
# 18                        [(coming to a) sudden stop]     [急, 停, 車]
# 19                              [embargo (on a ship)]  [出, 港, 停, 止]

# %%
df_vocab.to_json('vocab.jsonl', orient='records', lines=True)
